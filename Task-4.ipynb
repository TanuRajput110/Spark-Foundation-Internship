# %% [markdown]
# Graduate Rotational Internship (GRIP)
#
# January 2023 Batch
#
# Candidate Name : Tanu Rajput

# %% [markdown]
# # Task 4 : Exploratory Data Analysis - Terrorism

# %% [markdown]
# objective- we have to find out the hot zone of terrorism.

# %% [markdown]
# ## 1. Importing all the libraries required for analysis

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 2.Importing and observing the data

# %%
data=pd.read_csv("Global Terrorism.csv", encoding="latin1")
df=pd.DataFrame(data)
print("Data has been successfully imported")
df.head()
# Out:
# C:\Users\91639\AppData\Local\Temp\ipykernel_26760\1250931079.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("Global Terrorism.csv", encoding="latin1")
# Data has been successfully imported
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# The data string is of latin1 encoding instead of UTF-8 encoding

# %% [markdown]
# ## 3.Dataset information

# %%
# dataset information including shape, number of missing and number of unique values by defining function
def information(df):

  '''to see the data information including shape, number of missing and number of unique values'''

  print(f"Dataset Shape: {df.shape}")
  information = pd.DataFrame(df.dtypes,columns=['dtypes']).reset_index()
  information['Name'] = information['index']
  information= information[['Name','dtypes']]
  information['Missing'] = df.isnull().sum().values    
  information['Uniques'] = df.nunique().values
  return information
result = information(df).sort_values('Missing', ascending= False)
print(result)
# Out:
# Dataset Shape: (181691, 135)
#                  Name   dtypes  Missing  Uniques
# 63          gsubname3   object   181671       14
# 96   weapsubtype4_txt   object   181621       16
# 95       weapsubtype4  float64   181621       16
# 93          weaptype4  float64   181618        5
# 94      weaptype4_txt   object   181618        5
# ..                ...      ...      ...      ...
# 27            suicide    int64        0        2
# 26            success    int64        0        2
# 21              crit3    int64        0        2
# 104          property    int64        0        3
# 0             eventid  float64        0      576
#
# [135 rows x 4 columns]

# %% [markdown]
# ## 3.Data Cleaning

# %%
#We have a lot of irrelevent columns,so we need to select only required column for analysis
df=df[["iyear","imonth","iday","country_txt","region_txt","provstate","city",
       "latitude","longitude","location","summary","attacktype1_txt","targtype1_txt",
       "gname","motive","weaptype1_txt","nkill","nwound","addnotes"]]

# %%
#Let's rename the columns name for better understanding
df.rename(columns={"iyear":"Year","imonth":"Month","iday":"Day","country_txt":"Country",
                   "region_txt":"Region","provstate":"Province/State","city":"City",
                   "latitude":"Latitude","longitude":"Longitude","location":"Location",
                   "summary":"Summary","attacktype1_txt":"Attack Type","targtype1_txt":"Target Type",
                   "gname":"Group Name","motive":"Motive","weaptype1_txt":"Weapon Type",
                   "nkill":"Killed","nwound":"Wounded","addnotes":"Add Notes"},inplace=True)

# %%
#checking of data information again

def information(df):

  '''to see the data information including shape, number of missing and number of unique values'''

  print(f"Dataset Shape: {df.shape}")
  information = pd.DataFrame(df.dtypes,columns=['dtypes']).reset_index()
  information['Name'] = information['index']
  information= information[['Name','dtypes']]
  information['Missing'] = df.isnull().sum().values    
  information['Uniques'] = df.nunique().values
  return information
result = information(df).sort_values('Missing', ascending= False)
print(result)
# Out:
# Dataset Shape: (181691, 19)
#               Name   dtypes  Missing  Uniques
# 18       Add Notes   object   153402    15429
# 14          Motive   object   131130    14490
# 9         Location   object   126196    44109
# 10         Summary   object    66129   112492
# 17         Wounded  float64    16311      238
# 16          Killed  float64    10313      205
# 8        Longitude  float64     4557    48039
# 7         Latitude  float64     4556    48322
# 6             City   object      434    36674
# 5   Province/State   object      421     2855
# 3          Country   object        0      205
# 4           Region   object        0       12
# 1            Month    int64        0       13
# 11     Attack Type   object        0        9
# 12     Target Type   object        0       22
# 13      Group Name   object        0     3537
# 2              Day    int64        0       32
# 15     Weapon Type   object        0       12
# 0             Year    int64        0       47

# %%
df[df.isnull()]
# Out:
#         Year  Month  Day Country Region Province/State City  Latitude  \
# 0        NaN    NaN  NaN     NaN    NaN            NaN  NaN       NaN
# 1        NaN    NaN  NaN     NaN    NaN            NaN  NaN       NaN
# 2        NaN    NaN  NaN     NaN    NaN            NaN  NaN       NaN
# 3        NaN    NaN  NaN     NaN    NaN            NaN  NaN       NaN
# 4        NaN    NaN  NaN     NaN    NaN            NaN  NaN       NaN
# ...      ...    ...  ...     ...    ...            ...  ...       ...
# 181686   NaN    NaN  NaN     NaN    NaN            NaN  NaN       NaN
# 181687   NaN    NaN  NaN     NaN    NaN            NaN  NaN       NaN
# 181688   NaN    NaN  NaN     NaN    NaN            NaN  NaN       NaN
# 181689   NaN    NaN  NaN     NaN    NaN            NaN  NaN       NaN
# 181690   NaN    NaN  NaN     NaN    NaN            NaN  NaN       NaN
#
#         Longitude Location Summary Attack Type Target Type Group Name Motive  \
# 0             NaN      NaN     NaN         NaN         NaN        NaN    NaN
# 1             NaN      NaN     NaN         NaN         NaN        NaN    NaN
# 2             NaN      NaN     NaN         NaN         NaN        NaN    NaN
# 3             NaN      NaN     NaN         NaN         NaN        NaN    NaN
# 4             NaN      NaN     NaN         NaN         NaN        NaN    NaN
# ...           ...      ...     ...         ...         ...        ...    ...
# 181686        NaN      NaN     NaN         NaN         NaN        NaN    NaN
# 181687        NaN      NaN     NaN         NaN         NaN        NaN    NaN
# 181688        NaN      NaN     NaN         NaN         NaN        NaN    NaN
# 181689        NaN      NaN     NaN         NaN         NaN        NaN    NaN
# 181690        NaN      NaN     NaN         NaN         NaN        NaN    NaN
#
#        Weapon Type  Killed  Wounded Add Notes
# 0              NaN     NaN      NaN       NaN
# 1              NaN     NaN      NaN       NaN
# 2              NaN     NaN      NaN       NaN
# 3              NaN     NaN      NaN       NaN
# 4              NaN     NaN      NaN       NaN
# ...            ...     ...      ...       ...
# 181686         NaN     NaN      NaN       NaN
# 181687         NaN     NaN      NaN       NaN
# 181688         NaN     NaN      NaN       NaN
# 181689         NaN     NaN      NaN       NaN
# 181690         NaN     NaN      NaN       NaN
#
# [181691 rows x 19 columns]

# %%
 for i in df.columns:
    t=df[df[i].isnull()]
    print(t)
# Out:
# Empty DataFrame
# Columns: [Year, Month, Day, Country, Region, Province/State, City, Latitude, Longitude, Location, Summary, Attack Type, Target Type, Group Name, Motive, Weapon Type, Killed, Wounded, Add Notes]
# Index: []
# Empty DataFrame
# Columns: [Year, Month, Day, Country, Region, Province/State, City, Latitude, Longitude, Location, Summary, Attack Type, Target Type, Group Name, Motive, Weapon Type, Killed, Wounded, Add Notes]
# Index: []
# Empty DataFrame
# Columns: [Year, Month, Day, Country, Region, Province/State, City, Latitude, Longitude, Location, Summary, Attack Type, Target Type, Group Name, Motive, Weapon Type, Killed, Wounded, Add Notes]
# Index: []
# Empty DataFrame
# Columns: [Year, Month, Day, Country, Region, Province/State, City, Latitude, Longitude, Location, Summary, Attack Type, Target Type, Group Name, Motive, Weapon Type, Killed, Wounded, Add Notes]
# Index: []
# Empty DataFrame
# Columns: [Year, Month, Day, Country, Region, Province/State, City, Latitude, Longitude, Location, Summary, Attack Type, Target Type, Group Name, Motive, Weapon Type, Killed, Wounded, Add Notes]
# Index: []
#         Year  Month  Day             Country                       Region  \
# 0       1970      7    2  Dominican Republic  Central America & Caribbean
# 162     1970      3   31               Japan                    East Asia
# 1229    1972      4    4              Canada                North America
# 1568    1972      9   28       United States                North America
# 1617    1972     11    8              Mexico                North America
# ...      ...    ...  ...                 ...                          ...
# 82423   2007      2   18              Russia               Eastern Europe
# 82461   2007      2   21            Thailand               Southeast Asia
# 90671   2009      2   11              Russia               Eastern Europe
# 170978  2017      1    7       United States                North America
# 171830  2017      2    6       United States                North America
#
#        Province/State              City   Latitude   Longitude  \
# 0                 NaN     Santo Domingo  18.456792  -69.951164
# 162               NaN           Fukouka  33.580412  130.396361
# 1229              NaN          Montreal  45.508670  -73.553992
# 1568              NaN        Washington  38.908642  -77.015381
# 1617              NaN         Monterrey  25.673211 -100.309201
# ...               ...               ...        ...         ...
# 82423             NaN  Saint Petersburg  59.853371   30.348433
# 82461             NaN      Khayoh Mahti   6.681318  101.587340
# 90671             NaN          Vorenezh  51.650000   39.200000
# 170978            NaN       Hudson Bend  30.411172  -97.930155
# 171830            NaN        Manchester  42.993611  -71.486401
#
#                                                  Location  \
# 0                                                     NaN
# 162                                                   NaN
# 1229                                                  NaN
# 1568                                                  NaN
# 1617                                                  NaN
# ...                                                   ...
# 82423   The incident occurred in the Vladimirsky neigh...
# 82461         The incident cocurred in Sai Buri district.
# 90671        The attack occurred in the city of Voronezh.
# 170978                                                NaN
# 171830  The incident occurred in the Notre Dame neighb...
#
#                                                   Summary  \
# 0                                                     NaN
# 162                                                   NaN
# 1229                                                  NaN
# 1568    09/28/1972: A letter bomb addressed to the Isr...
# 1617                                                  NaN
# ...                                                   ...
# 82423   02/18/2007: A bomb exploded at a McDonalds re...
# 82461   02/21/2007: Around 8 am local time, Muslim ins...
# 90671   02/11/2009: On Wednesday night, in Voronezh, R...
# 170978  01/07/2017: Assailants set fire to the Islamic...
# 171830  02/06/2017: Assailants robbed and set fire to ...
#
#                            Attack Type                     Target Type  \
# 0                        Assassination     Private Citizens & Property
# 162                          Hijacking             Airports & Aircraft
# 1229                 Bombing/Explosion            Government (General)
# 1568                     Assassination         Government (Diplomatic)
# 1617                         Hijacking             Airports & Aircraft
# ...                                ...                             ...
# 82423                Bombing/Explosion                        Business
# 82461                Bombing/Explosion                        Military
# 90671                    Armed Assault            Government (General)
# 170978  Facility/Infrastructure Attack  Religious Figures/Institutions
# 171830  Facility/Infrastructure Attack                        Business
#
#                      Group Name  \
# 0                        MANO-D
# 162     Japanese Red Army (JRA)
# 1229                 Young Cuba
# 1568            Black September
# 1617                    Unknown
# ...                         ...
# 82423                   Unknown
# 82461                   Unknown
# 90671                   Unknown
# 170978   Anti-Muslim extremists
# 171830             Ku Klux Klan
#
#                                                    Motive Weapon Type  Killed  \
# 0                                                     NaN     Unknown     1.0
# 162                                                   NaN  Explosives     0.0
# 1229                                                  NaN  Explosives     1.0
# 1568                                                  NaN  Explosives     0.0
# 1617                                                  NaN    Firearms     0.0
# ...                                                   ...         ...     ...
# 82423                                             Unknown  Explosives     0.0
# 82461                                             Unknown  Explosives     0.0
# 90671      The specific motive for the attack is unknown.    Firearms     0.0
# 170978                                                NaN  Incendiary     0.0
# 171830  In a note left at the scene, assailants spray-...  Incendiary     0.0
#
#         Wounded                                          Add Notes
# 0           0.0                                                NaN
# 162         0.0                                                NaN
# 1229        7.0                                                NaN
# 1568        0.0                                                NaN
# 1617        0.0                                                NaN
# ...         ...                                                ...
# 82423       NaN                                                NaN
# 82461       3.0                                                NaN
# 90671       1.0                                                NaN
# 170978      0.0  There is doubt that this incident meets terror...
# 171830      0.0                                                NaN
#
# [421 rows x 19 columns]
#         Year  Month  Day      Country                      Region  \
# 79458   2006      1   19     Thailand              Southeast Asia
# 79459   2006      1   19     Thailand              Southeast Asia
# 79550   2006      1   24     Thailand              Southeast Asia
# 79583   2006      1   27     Thailand              Southeast Asia
# 79952   2006      2   21     Thailand              Southeast Asia
# ...      ...    ...  ...          ...                         ...
# 103120  2011      9   17        Libya  Middle East & North Africa
# 103403  2011     10   10         Iraq  Middle East & North Africa
# 103453  2011     10   14    Indonesia              Southeast Asia
# 103530  2011     10   21    Indonesia              Southeast Asia
# 103543  2011     10   23  Afghanistan                  South Asia
#
#          Province/State City   Latitude   Longitude  \
# 79458        Narathiwat  NaN   6.190088  101.797961
# 79459           Pattani  NaN   6.700696  101.433915
# 79550           Pattani  NaN   6.700696  101.433915
# 79583              Yala  NaN   6.202025  101.252379
# 79952   Yala (Province)  NaN   6.202025  101.252379
# ...                 ...  ...        ...         ...
# 103120         Mistrata  NaN        NaN         NaN
# 103403            Basra  NaN  30.293114   47.292389
# 103453            Papua  NaN  -2.534382  140.709304
# 103530            Papua  NaN  -2.534382  140.709304
# 103543           Parwan  NaN  34.963098   68.810885
#
#                                                  Location  \
# 79458                             No city name was given.
# 79459                             No city name was given.
# 79550   The city where the incident took place was not...
# 79583   The city where the incident took place was not...
# 79952                                                 NaN
# ...                                                   ...
# 103120  The attack took place on an airplane over the ...
# 103403  The attempted bombing occurred at a pipeline i...
# 103453  The attack occurred on Tanggul Timur road near...
# 103530  The attack occurred at a mine in an unspecifie...
# 103543  The attack occurred in an unknown area of the ...
#
#                                                   Summary        Attack Type  \
# 79458   01/19/2006: Suspected Islamic militants shot a...      Armed Assault
# 79459   01/19/2006: Suspected Islamic militants shot a...      Armed Assault
# 79550   01/24/2006: A Muslim government employee in Pa...      Armed Assault
# 79583   01/27/2006: Apisith Gueaji, a former army rang...      Armed Assault
# 79952   02/21/2006: Suspected Islamic militants shot a...      Armed Assault
# ...                                                   ...                ...
# 103120  09/17/2011: On Saturday, over the town of Bani...      Armed Assault
# 103403  10/10/2011: On Monday night, in an unknown are...  Bombing/Explosion
# 103453  10/14/2011: On Friday afternoon at 1545, near ...      Armed Assault
# 103530  10/21/2011: On Friday morning, in an unspecifi...      Armed Assault
# 103543  10/23/2011: On Sunday, in an unknown area of P...      Assassination
#
#                         Target Type Group Name  \
# 79458   Private Citizens & Property    Unknown
# 79459   Private Citizens & Property    Unknown
# 79550          Government (General)    Unknown
# 79583   Private Citizens & Property    Unknown
# 79952                        Police    Unknown
# ...                             ...        ...
# 103120          Airports & Aircraft    Unknown
# 103403                    Utilities    Unknown
# 103453                     Military    Unknown
# 103530  Private Citizens & Property    Unknown
# 103543         Government (General)    Unknown
#
#                                                 Motive Weapon Type  Killed  \
# 79458                                          Unknown    Firearms     1.0
# 79459                                          Unknown    Firearms     1.0
# 79550                                          Unknown    Firearms     1.0
# 79583                                          Unknown    Firearms     1.0
# 79952                                          Unknown    Firearms     2.0
# ...                                                ...         ...     ...
# 103120  The specific motive for the attack is unknown.    Firearms     0.0
# 103403  The specific motive for the attack is unknown.  Explosives     0.0
# 103453  The specific motive for the attack is unknown.    Firearms     3.0
# 103530  The specific motive for the attack is unknown.    Firearms     3.0
# 103543  The specific motive for the attack is unknown.  Explosives     1.0
#
#         Wounded                                          Add Notes
# 79458       0.0                                                NaN
# 79459       0.0                                                NaN
# 79550       0.0                                                NaN
# 79583       0.0                                                NaN
# 79952       0.0                                                NaN
# ...         ...                                                ...
# 103120      0.0  It is unclear whether or not anti-aircraft gun...
# 103403      0.0                                                NaN
# 103453      3.0                                                NaN
# 103530      1.0                                                NaN
# 103543      0.0                                                NaN
#
# [434 rows x 19 columns]
#         Year  Month  Day      Country                      Region  \
# 16      1970      1   11     Ethiopia          Sub-Saharan Africa
# 103     1970      3    3        Spain              Western Europe
# 132     1970      3   14     Ethiopia          Sub-Saharan Africa
# 165     1970      4    0     Ethiopia          Sub-Saharan Africa
# 210     1970      4   21  Philippines              Southeast Asia
# ...      ...    ...  ...          ...                         ...
# 180885  2017     11   28     Cameroon          Sub-Saharan Africa
# 181112  2017     12   11         Iraq  Middle East & North Africa
# 181300  2017     12   13       Turkey  Middle East & North Africa
# 181351  2017     12   16        Syria  Middle East & North Africa
# 181542  2017     12   25         Chad          Sub-Saharan Africa
#
#        Province/State           City  Latitude  Longitude  \
# 16            Unknown        Unknown       NaN        NaN
# 103           Unknown        Unknown       NaN        NaN
# 132           Unknown        Unknown       NaN        NaN
# 165           Unknown        Unknown       NaN        NaN
# 210           Unknown        Cauayan       NaN        NaN
# ...               ...            ...       ...        ...
# 180885        Unknown        Unknown       NaN        NaN
# 181112        Unknown        Unknown       NaN        NaN
# 181300        Unknown        Unknown       NaN        NaN
# 181351        Unknown        Unknown       NaN        NaN
# 181542        Unknown  Chre district       NaN        NaN
#
#                                                  Location  \
# 16                                                    NaN
# 103                                                   NaN
# 132                                                   NaN
# 165                                                   NaN
# 210                                                   NaN
# ...                                                   ...
# 180885                                                NaN
# 181112  The incident occurred in the northern part of ...
# 181300  The incident occurred in the southeastern part...
# 181351                                                NaN
# 181542  The incident occurred near the border with Libya.
#
#                                                   Summary  \
# 16                                                    NaN
# 103                                                   NaN
# 132                                                   NaN
# 165                                                   NaN
# 210                                                   NaN
# ...                                                   ...
# 180885  11/28/2017: Assailants abducted eight people f...
# 181112  12/00/2017: Sometime between December 1, 2017 ...
# 181300  12/00/2017: Sometime between December 10, 2017...
# 181351  12/00/2017: Sometime between December 1, 2017 ...
# 181542  12/25/2017: Assailants attacked a gold mine in...
#
#                         Attack Type                  Target Type  \
# 16                          Unknown                     Military
# 103     Hostage Taking (Kidnapping)         Government (General)
# 132     Hostage Taking (Kidnapping)          Journalists & Media
# 165     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 210               Bombing/Explosion          Airports & Aircraft
# ...                             ...                          ...
# 180885  Hostage Taking (Kidnapping)  Private Citizens & Property
# 181112            Bombing/Explosion                    Utilities
# 181300                      Unknown  Private Citizens & Property
# 181351  Hostage Taking (Kidnapping)  Private Citizens & Property
# 181542                      Unknown                     Business
#
#                                          Group Name Motive Weapon Type  \
# 16                        Eritrean Liberation Front    NaN     Unknown
# 103                                1st of May Group    NaN     Unknown
# 132                       Eritrean Liberation Front    NaN     Unknown
# 165                       Eritrean Liberation Front    NaN     Unknown
# 210                                         Unknown    NaN  Explosives
# ...                                             ...    ...         ...
# 180885                                      Unknown    NaN    Firearms
# 181112  Islamic State of Iraq and the Levant (ISIL)    NaN  Explosives
# 181300               Kurdistan Workers' Party (PKK)    NaN     Unknown
# 181351                        Hay'at Tahrir al-Sham    NaN     Unknown
# 181542                                      Unknown    NaN     Unknown
#
#         Killed  Wounded                                          Add Notes
# 16         1.0      0.0                                                NaN
# 103        0.0      0.0                                                NaN
# 132        0.0      0.0                                                NaN
# 165        0.0      0.0                                                NaN
# 210       36.0      0.0                                                NaN
# ...        ...      ...                                                ...
# 180885     0.0      2.0  Casualty and hostage numbers represent a divis...
# 181112     0.0      0.0                                                NaN
# 181300     1.0      0.0                                                NaN
# 181351     0.0      0.0            The victims included Abdal-Geniy Ahmad.
# 181542    12.0      NaN                                                NaN
#
# [4556 rows x 19 columns]
#         Year  Month  Day      Country                      Region  \
# 16      1970      1   11     Ethiopia          Sub-Saharan Africa
# 103     1970      3    3        Spain              Western Europe
# 132     1970      3   14     Ethiopia          Sub-Saharan Africa
# 165     1970      4    0     Ethiopia          Sub-Saharan Africa
# 210     1970      4   21  Philippines              Southeast Asia
# ...      ...    ...  ...          ...                         ...
# 180885  2017     11   28     Cameroon          Sub-Saharan Africa
# 181112  2017     12   11         Iraq  Middle East & North Africa
# 181300  2017     12   13       Turkey  Middle East & North Africa
# 181351  2017     12   16        Syria  Middle East & North Africa
# 181542  2017     12   25         Chad          Sub-Saharan Africa
#
#        Province/State           City  Latitude  Longitude  \
# 16            Unknown        Unknown       NaN        NaN
# 103           Unknown        Unknown       NaN        NaN
# 132           Unknown        Unknown       NaN        NaN
# 165           Unknown        Unknown       NaN        NaN
# 210           Unknown        Cauayan       NaN        NaN
# ...               ...            ...       ...        ...
# 180885        Unknown        Unknown       NaN        NaN
# 181112        Unknown        Unknown       NaN        NaN
# 181300        Unknown        Unknown       NaN        NaN
# 181351        Unknown        Unknown       NaN        NaN
# 181542        Unknown  Chre district       NaN        NaN
#
#                                                  Location  \
# 16                                                    NaN
# 103                                                   NaN
# 132                                                   NaN
# 165                                                   NaN
# 210                                                   NaN
# ...                                                   ...
# 180885                                                NaN
# 181112  The incident occurred in the northern part of ...
# 181300  The incident occurred in the southeastern part...
# 181351                                                NaN
# 181542  The incident occurred near the border with Libya.
#
#                                                   Summary  \
# 16                                                    NaN
# 103                                                   NaN
# 132                                                   NaN
# 165                                                   NaN
# 210                                                   NaN
# ...                                                   ...
# 180885  11/28/2017: Assailants abducted eight people f...
# 181112  12/00/2017: Sometime between December 1, 2017 ...
# 181300  12/00/2017: Sometime between December 10, 2017...
# 181351  12/00/2017: Sometime between December 1, 2017 ...
# 181542  12/25/2017: Assailants attacked a gold mine in...
#
#                         Attack Type                  Target Type  \
# 16                          Unknown                     Military
# 103     Hostage Taking (Kidnapping)         Government (General)
# 132     Hostage Taking (Kidnapping)          Journalists & Media
# 165     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 210               Bombing/Explosion          Airports & Aircraft
# ...                             ...                          ...
# 180885  Hostage Taking (Kidnapping)  Private Citizens & Property
# 181112            Bombing/Explosion                    Utilities
# 181300                      Unknown  Private Citizens & Property
# 181351  Hostage Taking (Kidnapping)  Private Citizens & Property
# 181542                      Unknown                     Business
#
#                                          Group Name Motive Weapon Type  \
# 16                        Eritrean Liberation Front    NaN     Unknown
# 103                                1st of May Group    NaN     Unknown
# 132                       Eritrean Liberation Front    NaN     Unknown
# 165                       Eritrean Liberation Front    NaN     Unknown
# 210                                         Unknown    NaN  Explosives
# ...                                             ...    ...         ...
# 180885                                      Unknown    NaN    Firearms
# 181112  Islamic State of Iraq and the Levant (ISIL)    NaN  Explosives
# 181300               Kurdistan Workers' Party (PKK)    NaN     Unknown
# 181351                        Hay'at Tahrir al-Sham    NaN     Unknown
# 181542                                      Unknown    NaN     Unknown
#
#         Killed  Wounded                                          Add Notes
# 16         1.0      0.0                                                NaN
# 103        0.0      0.0                                                NaN
# 132        0.0      0.0                                                NaN
# 165        0.0      0.0                                                NaN
# 210       36.0      0.0                                                NaN
# ...        ...      ...                                                ...
# 180885     0.0      2.0  Casualty and hostage numbers represent a divis...
# 181112     0.0      0.0                                                NaN
# 181300     1.0      0.0                                                NaN
# 181351     0.0      0.0            The victims included Abdal-Geniy Ahmad.
# 181542    12.0      NaN                                                NaN
#
# [4557 rows x 19 columns]
#         Year  Month  Day             Country                       Region  \
# 0       1970      7    2  Dominican Republic  Central America & Caribbean
# 1       1970      0    0              Mexico                North America
# 2       1970      1    0         Philippines               Southeast Asia
# 3       1970      1    0              Greece               Western Europe
# 4       1970      1    0               Japan                    East Asia
# ...      ...    ...  ...                 ...                          ...
# 181678  2017     12   30         Philippines               Southeast Asia
# 181680  2017     12   31             Somalia           Sub-Saharan Africa
# 181683  2017     12   31         Afghanistan                   South Asia
# 181685  2017     12   31         Afghanistan                   South Asia
# 181690  2017     12   31         Philippines               Southeast Asia
#
#         Province/State               City   Latitude   Longitude Location  \
# 0                  NaN      Santo Domingo  18.456792  -69.951164      NaN
# 1              Federal        Mexico city  19.371887  -99.086624      NaN
# 2               Tarlac            Unknown  15.478598  120.599741      NaN
# 3               Attica             Athens  37.997490   23.762728      NaN
# 4              Fukouka            Fukouka  33.580412  130.396361      NaN
# ...                ...                ...        ...         ...      ...
# 181678  North Cotabato     Pikit district   7.053143  124.619270      NaN
# 181680          Bakool              Wajid   3.810951   43.246506      NaN
# 181683          Faryab  Kohistan district  35.315467   64.815508      NaN
# 181685          Faryab            Maymana  35.921051   64.774544      NaN
# 181690     Maguindanao      Cotabato City   7.209594  124.241966      NaN
#
#                                                   Summary  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181678  12/30/2017: Assailants threw a grenade at a st...
# 181680  12/31/2017: Assailants fired mortars at an Eth...
# 181683  12/31/2017: Assailants attacked the house of a...
# 181685  12/31/2017: An explosive device detonated at a...
# 181690  12/31/2017: An explosive device was discovered...
#
#                            Attack Type                   Target Type  \
# 0                        Assassination   Private Citizens & Property
# 1          Hostage Taking (Kidnapping)       Government (Diplomatic)
# 2                        Assassination           Journalists & Media
# 3                    Bombing/Explosion       Government (Diplomatic)
# 4       Facility/Infrastructure Attack       Government (Diplomatic)
# ...                                ...                           ...
# 181678               Bombing/Explosion                      Business
# 181680               Bombing/Explosion                      Military
# 181683                   Armed Assault  Terrorists/Non-State Militia
# 181685               Bombing/Explosion                      Business
# 181690               Bombing/Explosion                       Unknown
#
#                                 Group Name  \
# 0                                   MANO-D
# 1       23rd of September Communist League
# 2                                  Unknown
# 3                                  Unknown
# 4                                  Unknown
# ...                                    ...
# 181678                             Unknown
# 181680                          Al-Shabaab
# 181683                             Taliban
# 181685                             Unknown
# 181690                             Unknown
#
#                                                    Motive Weapon Type  Killed  \
# 0                                                     NaN     Unknown     1.0
# 1                                                     NaN     Unknown     0.0
# 2                                                     NaN     Unknown     1.0
# 3                                                     NaN  Explosives     NaN
# 4                                                     NaN  Incendiary     NaN
# ...                                                   ...         ...     ...
# 181678                                                NaN  Explosives     1.0
# 181680                                                NaN  Explosives     0.0
# 181683  The specific motive is unknown; however, sourc...    Firearms     6.0
# 181685                                                NaN  Explosives     0.0
# 181690                                                NaN  Explosives     0.0
#
#         Wounded                                          Add Notes
# 0           0.0                                                NaN
# 1           0.0                                                NaN
# 2           0.0                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# ...         ...                                                ...
# 181678      1.0  The victims included the owner, Norodin Pacaln...
# 181680      0.0                                                NaN
# 181683      0.0                                                NaN
# 181685      4.0                                                NaN
# 181690      0.0                                                NaN
#
# [126196 rows x 19 columns]
#        Year  Month  Day             Country                       Region  \
# 0      1970      7    2  Dominican Republic  Central America & Caribbean
# 1      1970      0    0              Mexico                North America
# 2      1970      1    0         Philippines               Southeast Asia
# 3      1970      1    0              Greece               Western Europe
# 4      1970      1    0               Japan                    East Asia
# ...     ...    ...  ...                 ...                          ...
# 67502  1997     12   31            Thailand               Southeast Asia
# 67503  1997     12   31           Argentina                South America
# 67504  1997     12   31              Brazil                South America
# 67505  1997     12   31             Burundi           Sub-Saharan Africa
# 67506  1997     12   31      United Kingdom               Western Europe
#
#          Province/State              City   Latitude   Longitude Location  \
# 0                   NaN     Santo Domingo  18.456792  -69.951164      NaN
# 1               Federal       Mexico city  19.371887  -99.086624      NaN
# 2                Tarlac           Unknown  15.478598  120.599741      NaN
# 3                Attica            Athens  37.997490   23.762728      NaN
# 4               Fukouka           Fukouka  33.580412  130.396361      NaN
# ...                 ...               ...        ...         ...      ...
# 67502              Yala  Than To district   6.166837  101.190053      NaN
# 67503      Buenos Aires      Buenos Aires -34.617680  -58.444435      NaN
# 67504    Espirito Santo         Cariacica -20.264305  -40.420312      NaN
# 67505   Bujumbura Rural          Kanyosha  -3.412554   29.408034      NaN
# 67506  Northern Ireland           Belfast  54.607712   -5.956210      NaN
#
#       Summary                     Attack Type                  Target Type  \
# 0         NaN                   Assassination  Private Citizens & Property
# 1         NaN     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2         NaN                   Assassination          Journalists & Media
# 3         NaN               Bombing/Explosion      Government (Diplomatic)
# 4         NaN  Facility/Infrastructure Attack      Government (Diplomatic)
# ...       ...                             ...                          ...
# 67502     NaN               Bombing/Explosion               Transportation
# 67503     NaN                         Unknown  Private Citizens & Property
# 67504     NaN                   Assassination          Journalists & Media
# 67505     NaN                         Unknown  Private Citizens & Property
# 67506     NaN                   Armed Assault                     Business
#
#                                Group Name Motive Weapon Type  Killed  Wounded  \
# 0                                  MANO-D    NaN     Unknown     1.0      0.0
# 1      23rd of September Communist League    NaN     Unknown     0.0      0.0
# 2                                 Unknown    NaN     Unknown     1.0      0.0
# 3                                 Unknown    NaN  Explosives     NaN      NaN
# 4                                 Unknown    NaN  Incendiary     NaN      NaN
# ...                                   ...    ...         ...     ...      ...
# 67502                             Unknown    NaN  Explosives     0.0      0.0
# 67503                             Unknown    NaN     Unknown     0.0      0.0
# 67504                             Unknown    NaN    Firearms     1.0      0.0
# 67505                             Unknown    NaN     Unknown     2.0      0.0
# 67506       Ulster Freedom Fighters (UFF)    NaN    Firearms     1.0      NaN
#
#       Add Notes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 67502       NaN
# 67503       NaN
# 67504       NaN
# 67505       NaN
# 67506       NaN
#
# [66129 rows x 19 columns]
# Empty DataFrame
# Columns: [Year, Month, Day, Country, Region, Province/State, City, Latitude, Longitude, Location, Summary, Attack Type, Target Type, Group Name, Motive, Weapon Type, Killed, Wounded, Add Notes]
# Index: []
# Empty DataFrame
# Columns: [Year, Month, Day, Country, Region, Province/State, City, Latitude, Longitude, Location, Summary, Attack Type, Target Type, Group Name, Motive, Weapon Type, Killed, Wounded, Add Notes]
# Index: []
# Empty DataFrame
# Columns: [Year, Month, Day, Country, Region, Province/State, City, Latitude, Longitude, Location, Summary, Attack Type, Target Type, Group Name, Motive, Weapon Type, Killed, Wounded, Add Notes]
# Index: []
#         Year  Month  Day             Country                       Region  \
# 0       1970      7    2  Dominican Republic  Central America & Caribbean
# 1       1970      0    0              Mexico                North America
# 2       1970      1    0         Philippines               Southeast Asia
# 3       1970      1    0              Greece               Western Europe
# 4       1970      1    0               Japan                    East Asia
# ...      ...    ...  ...                 ...                          ...
# 181686  2017     12   31             Somalia           Sub-Saharan Africa
# 181687  2017     12   31               Syria   Middle East & North Africa
# 181688  2017     12   31         Philippines               Southeast Asia
# 181689  2017     12   31               India                   South Asia
# 181690  2017     12   31         Philippines               Southeast Asia
#
#          Province/State           City   Latitude   Longitude  \
# 0                   NaN  Santo Domingo  18.456792  -69.951164
# 1               Federal    Mexico city  19.371887  -99.086624
# 2                Tarlac        Unknown  15.478598  120.599741
# 3                Attica         Athens  37.997490   23.762728
# 4               Fukouka        Fukouka  33.580412  130.396361
# ...                 ...            ...        ...         ...
# 181686  Middle Shebelle  Ceelka Geelow   2.359673   45.385034
# 181687         Lattakia         Jableh  35.407278   35.942679
# 181688      Maguindanao       Kubentog   6.900742  124.437908
# 181689          Manipur         Imphal  24.798346   93.940430
# 181690      Maguindanao  Cotabato City   7.209594  124.241966
#
#                                                  Location  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686     The incident occurred near the town of Balcad.
# 181687     The incident occurred at the Humaymim Airport.
# 181688  The incident occurred in the Datu Hoffer distr...
# 181689  The incident occurred in the Mantripukhri neig...
# 181690                                                NaN
#
#                                                   Summary  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  12/31/2017: Assailants opened fire on a Somali...
# 181687  12/31/2017: Assailants launched mortars at the...
# 181688  12/31/2017: Assailants set fire to houses in K...
# 181689  12/31/2017: Assailants threw a grenade at a Fo...
# 181690  12/31/2017: An explosive device was discovered...
#
#                            Attack Type                  Target Type  \
# 0                        Assassination  Private Citizens & Property
# 1          Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                        Assassination          Journalists & Media
# 3                    Bombing/Explosion      Government (Diplomatic)
# 4       Facility/Infrastructure Attack      Government (Diplomatic)
# ...                                ...                          ...
# 181686                   Armed Assault                     Military
# 181687               Bombing/Explosion                     Military
# 181688  Facility/Infrastructure Attack  Private Citizens & Property
# 181689               Bombing/Explosion         Government (General)
# 181690               Bombing/Explosion                      Unknown
#
#                                         Group Name Motive Weapon Type  Killed  \
# 0                                           MANO-D    NaN     Unknown     1.0
# 1               23rd of September Communist League    NaN     Unknown     0.0
# 2                                          Unknown    NaN     Unknown     1.0
# 3                                          Unknown    NaN  Explosives     NaN
# 4                                          Unknown    NaN  Incendiary     NaN
# ...                                            ...    ...         ...     ...
# 181686                                  Al-Shabaab    NaN    Firearms     1.0
# 181687                           Muslim extremists    NaN  Explosives     2.0
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)    NaN  Incendiary     0.0
# 181689                                     Unknown    NaN  Explosives     0.0
# 181690                                     Unknown    NaN  Explosives     0.0
#
#         Wounded Add Notes
# 0           0.0       NaN
# 1           0.0       NaN
# 2           0.0       NaN
# 3           NaN       NaN
# 4           NaN       NaN
# ...         ...       ...
# 181686      2.0       NaN
# 181687      7.0       NaN
# 181688      0.0       NaN
# 181689      0.0       NaN
# 181690      0.0       NaN
#
# [131130 rows x 19 columns]
# Empty DataFrame
# Columns: [Year, Month, Day, Country, Region, Province/State, City, Latitude, Longitude, Location, Summary, Attack Type, Target Type, Group Name, Motive, Weapon Type, Killed, Wounded, Add Notes]
# Index: []
#         Year  Month  Day             Country                      Region  \
# 3       1970      1    0              Greece              Western Europe
# 4       1970      1    0               Japan                   East Asia
# 15      1970      1   10  East Germany (GDR)              Eastern Europe
# 34      1970      1   28  East Germany (GDR)              Eastern Europe
# 95      1970      2   28              Jordan  Middle East & North Africa
# ...      ...    ...  ...                 ...                         ...
# 181636  2017     12   29         Afghanistan                  South Asia
# 181640  2017     12   29                Iraq  Middle East & North Africa
# 181662  2017     12   30         Philippines              Southeast Asia
# 181666  2017     12   30             Nigeria          Sub-Saharan Africa
# 181667  2017     12   30               Syria  Middle East & North Africa
#
#         Province/State              City   Latitude   Longitude  \
# 3               Attica            Athens  37.997490   23.762728
# 4              Fukouka           Fukouka  33.580412  130.396361
# 15              Berlin            Berlin  52.501530   13.401851
# 34              Berlin            Berlin  52.501530   13.401851
# 95              Khalil            Hebron  31.530243   35.094162
# ...                ...               ...        ...         ...
# 181636         Jawzjan   Darzab district  35.974879   65.381563
# 181640         Nineveh     Baaj district  36.139762   41.312916
# 181662  Davao Oriental         Tarragona   7.042777  126.449221
# 181666           Borno  Konduga district  11.492144   12.969724
# 181667        Damascus           Harasta  33.561504   36.368763
#
#                                                  Location  \
# 3                                                     NaN
# 4                                                     NaN
# 15                                                    NaN
# 34                                                    NaN
# 95                                                    NaN
# ...                                                   ...
# 181636                                                NaN
# 181640  The incident occurred along the Iraq-Syria bor...
# 181662                                                NaN
# 181666  The incident occurred along the Maiduguri-Damb...
# 181667                                                NaN
#
#                                                   Summary  \
# 3                                                     NaN
# 4                                                     NaN
# 15                                                    NaN
# 34                                                    NaN
# 95                                                    NaN
# ...                                                   ...
# 181636  12/29/2017: Assailants abducted 12 religious s...
# 181640  12/29/2017: Assailants opened fire on Iraqi Ar...
# 181662  12/30/2017: Assailants opened fire on and deto...
# 181666  12/30/2017: Assailants attacked a convoy along...
# 181667  12/30/2017: A suicide bomber detonated an expl...
#
#                            Attack Type                     Target Type  \
# 3                    Bombing/Explosion         Government (Diplomatic)
# 4       Facility/Infrastructure Attack         Government (Diplomatic)
# 15                   Bombing/Explosion            Government (General)
# 34      Facility/Infrastructure Attack                          Police
# 95                       Armed Assault                        Tourists
# ...                                ...                             ...
# 181636     Hostage Taking (Kidnapping)  Religious Figures/Institutions
# 181640                   Armed Assault                        Military
# 181662               Bombing/Explosion                        Military
# 181666  Facility/Infrastructure Attack     Private Citizens & Property
# 181667               Bombing/Explosion                        Military
#
#                                    Group Name Motive Weapon Type  Killed  \
# 3                                     Unknown    NaN  Explosives     NaN
# 4                                     Unknown    NaN  Incendiary     NaN
# 15                                  Commune 1    NaN  Explosives     NaN
# 34                                    Unknown    NaN  Incendiary     NaN
# 95                                    Unknown    NaN    Firearms     NaN
# ...                                       ...    ...         ...     ...
# 181636  Khorasan Chapter of the Islamic State    NaN     Unknown     NaN
# 181640                                Unknown    NaN    Firearms     NaN
# 181662                New People's Army (NPA)    NaN  Explosives     NaN
# 181666                             Boko Haram    NaN     Unknown     NaN
# 181667                  Hay'at Tahrir al-Sham    NaN  Explosives     NaN
#
#         Wounded Add Notes
# 3           NaN       NaN
# 4           NaN       NaN
# 15          NaN       NaN
# 34          NaN       NaN
# 95          NaN       NaN
# ...         ...       ...
# 181636      NaN       NaN
# 181640      0.0       NaN
# 181662      2.0       NaN
# 181666      NaN       NaN
# 181667      NaN       NaN
#
# [10313 rows x 19 columns]
#         Year  Month  Day             Country                      Region  \
# 3       1970      1    0              Greece              Western Europe
# 4       1970      1    0               Japan                   East Asia
# 15      1970      1   10  East Germany (GDR)              Eastern Europe
# 34      1970      1   28  East Germany (GDR)              Eastern Europe
# 59      1970      2   10  West Germany (FRG)              Western Europe
# ...      ...    ...  ...                 ...                         ...
# 181654  2017     12   30             Nigeria          Sub-Saharan Africa
# 181655  2017     12   30             Nigeria          Sub-Saharan Africa
# 181656  2017     12   30             Nigeria          Sub-Saharan Africa
# 181666  2017     12   30             Nigeria          Sub-Saharan Africa
# 181667  2017     12   30               Syria  Middle East & North Africa
#
#        Province/State              City   Latitude   Longitude  \
# 3              Attica            Athens  37.997490   23.762728
# 4             Fukouka           Fukouka  33.580412  130.396361
# 15             Berlin            Berlin  52.501530   13.401851
# 34             Berlin            Berlin  52.501530   13.401851
# 59            Bavaria            Munich  48.139126   11.580186
# ...               ...               ...        ...         ...
# 181654          Borno              Mafa  11.923636   13.599695
# 181655           Yobe           Kanamma  13.099690   12.107900
# 181656          Borno             Maiwa  11.883003   13.455697
# 181666          Borno  Konduga district  11.492144   12.969724
# 181667       Damascus           Harasta  33.561504   36.368763
#
#                                                  Location  \
# 3                                                     NaN
# 4                                                     NaN
# 15                                                    NaN
# 34                                                    NaN
# 59                                                    NaN
# ...                                                   ...
# 181654                                                NaN
# 181655                                                NaN
# 181656  The incident occurred 20 kilometers from Maidu...
# 181666  The incident occurred along the Maiduguri-Damb...
# 181667                                                NaN
#
#                                                   Summary  \
# 3                                                     NaN
# 4                                                     NaN
# 15                                                    NaN
# 34                                                    NaN
# 59                                                    NaN
# ...                                                   ...
# 181654  12/30/2017: Assailants attacked internally dis...
# 181655  12/30/2017: Assailants attacked a military ins...
# 181656  12/30/2017: Assailants opened fire on loggers ...
# 181666  12/30/2017: Assailants attacked a convoy along...
# 181667  12/30/2017: A suicide bomber detonated an expl...
#
#                            Attack Type                  Target Type  \
# 3                    Bombing/Explosion      Government (Diplomatic)
# 4       Facility/Infrastructure Attack      Government (Diplomatic)
# 15                   Bombing/Explosion         Government (General)
# 34      Facility/Infrastructure Attack                       Police
# 59                       Armed Assault          Airports & Aircraft
# ...                                ...                          ...
# 181654                         Unknown  Private Citizens & Property
# 181655                   Armed Assault                     Military
# 181656                   Armed Assault  Private Citizens & Property
# 181666  Facility/Infrastructure Attack  Private Citizens & Property
# 181667               Bombing/Explosion                     Military
#
#                                                Group Name Motive Weapon Type  \
# 3                                                 Unknown    NaN  Explosives
# 4                                                 Unknown    NaN  Incendiary
# 15                                              Commune 1    NaN  Explosives
# 34                                                Unknown    NaN  Incendiary
# 59      Popular Front for the Liberation of Palestine ...    NaN    Firearms
# ...                                                   ...    ...         ...
# 181654                                         Boko Haram    NaN     Unknown
# 181655                                         Boko Haram    NaN    Firearms
# 181656                                         Boko Haram    NaN    Firearms
# 181666                                         Boko Haram    NaN     Unknown
# 181667                              Hay'at Tahrir al-Sham    NaN  Explosives
#
#         Killed  Wounded Add Notes
# 3          NaN      NaN       NaN
# 4          NaN      NaN       NaN
# 15         NaN      NaN       NaN
# 34         NaN      NaN       NaN
# 59         1.0      NaN       NaN
# ...        ...      ...       ...
# 181654    50.0      NaN       NaN
# 181655     5.0      NaN       NaN
# 181656    25.0      NaN       NaN
# 181666     NaN      NaN       NaN
# 181667     NaN      NaN       NaN
#
# [16311 rows x 19 columns]
#         Year  Month  Day             Country                       Region  \
# 0       1970      7    2  Dominican Republic  Central America & Caribbean
# 1       1970      0    0              Mexico                North America
# 2       1970      1    0         Philippines               Southeast Asia
# 3       1970      1    0              Greece               Western Europe
# 4       1970      1    0               Japan                    East Asia
# ...      ...    ...  ...                 ...                          ...
# 181686  2017     12   31             Somalia           Sub-Saharan Africa
# 181687  2017     12   31               Syria   Middle East & North Africa
# 181688  2017     12   31         Philippines               Southeast Asia
# 181689  2017     12   31               India                   South Asia
# 181690  2017     12   31         Philippines               Southeast Asia
#
#          Province/State           City   Latitude   Longitude  \
# 0                   NaN  Santo Domingo  18.456792  -69.951164
# 1               Federal    Mexico city  19.371887  -99.086624
# 2                Tarlac        Unknown  15.478598  120.599741
# 3                Attica         Athens  37.997490   23.762728
# 4               Fukouka        Fukouka  33.580412  130.396361
# ...                 ...            ...        ...         ...
# 181686  Middle Shebelle  Ceelka Geelow   2.359673   45.385034
# 181687         Lattakia         Jableh  35.407278   35.942679
# 181688      Maguindanao       Kubentog   6.900742  124.437908
# 181689          Manipur         Imphal  24.798346   93.940430
# 181690      Maguindanao  Cotabato City   7.209594  124.241966
#
#                                                  Location  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686     The incident occurred near the town of Balcad.
# 181687     The incident occurred at the Humaymim Airport.
# 181688  The incident occurred in the Datu Hoffer distr...
# 181689  The incident occurred in the Mantripukhri neig...
# 181690                                                NaN
#
#                                                   Summary  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  12/31/2017: Assailants opened fire on a Somali...
# 181687  12/31/2017: Assailants launched mortars at the...
# 181688  12/31/2017: Assailants set fire to houses in K...
# 181689  12/31/2017: Assailants threw a grenade at a Fo...
# 181690  12/31/2017: An explosive device was discovered...
#
#                            Attack Type                  Target Type  \
# 0                        Assassination  Private Citizens & Property
# 1          Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                        Assassination          Journalists & Media
# 3                    Bombing/Explosion      Government (Diplomatic)
# 4       Facility/Infrastructure Attack      Government (Diplomatic)
# ...                                ...                          ...
# 181686                   Armed Assault                     Military
# 181687               Bombing/Explosion                     Military
# 181688  Facility/Infrastructure Attack  Private Citizens & Property
# 181689               Bombing/Explosion         Government (General)
# 181690               Bombing/Explosion                      Unknown
#
#                                         Group Name Motive Weapon Type  Killed  \
# 0                                           MANO-D    NaN     Unknown     1.0
# 1               23rd of September Communist League    NaN     Unknown     0.0
# 2                                          Unknown    NaN     Unknown     1.0
# 3                                          Unknown    NaN  Explosives     NaN
# 4                                          Unknown    NaN  Incendiary     NaN
# ...                                            ...    ...         ...     ...
# 181686                                  Al-Shabaab    NaN    Firearms     1.0
# 181687                           Muslim extremists    NaN  Explosives     2.0
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)    NaN  Incendiary     0.0
# 181689                                     Unknown    NaN  Explosives     0.0
# 181690                                     Unknown    NaN  Explosives     0.0
#
#         Wounded Add Notes
# 0           0.0       NaN
# 1           0.0       NaN
# 2           0.0       NaN
# 3           NaN       NaN
# 4           NaN       NaN
# ...         ...       ...
# 181686      2.0       NaN
# 181687      7.0       NaN
# 181688      0.0       NaN
# 181689      0.0       NaN
# 181690      0.0       NaN
#
# [153402 rows x 19 columns]

# %%
#lets see unique values in each column
for i  in df.columns:
  print("\n")
  print(f"                        ---------------------------------------Unique Values of {i}----------------------------------------")
  print("\n")
  print(f"{df[i].unique()}")
  print("\n")
# Out:
#                         ---------------------------------------Unique Values of Year----------------------------------------
#
#
# [1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1986 1982
#  1983 1984 1985 1987 1988 1989 1990 1991 1992 1994 1995 1996 1997 1998
#  1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012
#  2013 2014 2015 2016 2017]
#
#
#
#
#                         ---------------------------------------Unique Values of Month----------------------------------------
#
#
# [ 7  0  1  2  3  4  5  6  8  9 10 11 12]
#
#
#
#
#                         ---------------------------------------Unique Values of Day----------------------------------------
#
#
# [ 2  0  1  3  6  8  9 10 11 12 13 14 15 19 20 21 22 25 26 27 28 30 31  4
#   7 16 17 18 23 24  5 29]
#
#
#
#
#                         ---------------------------------------Unique Values of Country----------------------------------------
#
#
# ['Dominican Republic' 'Mexico' 'Philippines' 'Greece' 'Japan'
#  'United States' 'Uruguay' 'Italy' 'East Germany (GDR)' 'Ethiopia'
#  'Guatemala' 'Venezuela' 'West Germany (FRG)' 'Switzerland' 'Jordan'
#  'Spain' 'Brazil' 'Egypt' 'Argentina' 'Lebanon' 'Ireland' 'Turkey'
#  'Paraguay' 'Iran' 'United Kingdom' 'Colombia' 'Bolivia' 'Nicaragua'
#  'Netherlands' 'Belgium' 'Canada' 'Australia' 'Pakistan' 'Zambia' 'Sweden'
#  'Costa Rica' 'South Yemen' 'Cambodia' 'Israel' 'Poland' 'Taiwan' 'Panama'
#  'Kuwait' 'West Bank and Gaza Strip' 'Austria' 'Czechoslovakia' 'India'
#  'France' 'South Vietnam' 'Brunei' 'Zaire'
#  "People's Republic of the Congo" 'Portugal' 'Algeria' 'El Salvador'
#  'Thailand' 'Haiti' 'Sudan' 'Morocco' 'Cyprus' 'Myanmar' 'Afghanistan'
#  'Peru' 'Chile' 'Honduras' 'Yugoslavia' 'Ecuador' 'New Zealand' 'Malaysia'
#  'Singapore' 'Botswana' 'Jamaica' 'Chad' 'North Yemen' 'Andorra' 'Syria'
#  'South Korea' 'United Arab Emirates' 'South Africa' 'Kenya' 'Iraq'
#  'Somalia' 'Tanzania' 'Sri Lanka' 'Namibia' 'Bahamas' 'Nigeria' 'Barbados'
#  'Trinidad and Tobago' 'Bangladesh' 'Angola' 'Mauritania' 'Saudi Arabia'
#  'Djibouti' 'Indonesia' 'Malta' 'Rhodesia' 'Soviet Union' 'Denmark'
#  'Western Sahara' 'Guyana' 'Mozambique' 'Tunisia' 'Uganda' 'Norway'
#  'Lesotho' 'Gabon' 'Libya' 'Bahrain' 'Hong Kong' 'Senegal' 'Zimbabwe'
#  'Guinea' 'Grenada' 'New Hebrides' 'Belize' 'Guadeloupe' 'Martinique'
#  'Vatican City' 'Albania' 'Central African Republic' 'Seychelles'
#  'Dominica' 'Qatar' 'Bulgaria' 'Suriname' 'Swaziland' 'Luxembourg'
#  'Iceland' 'French Guiana' 'Falkland Islands' 'Burkina Faso'
#  'New Caledonia' 'Romania' 'Niger' 'Nepal' 'Togo' 'Finland' 'Fiji' 'Ghana'
#  'Maldives' 'Mauritius' 'Hungary' 'Laos' 'Papua New Guinea' 'China'
#  'Liberia' 'Republic of the Congo' 'Mali' 'Germany' 'Yemen' 'Rwanda'
#  'Sierra Leone' 'Cameroon' 'Cuba' 'Croatia' 'Georgia' 'Azerbaijan'
#  'Madagascar' 'Lithuania' 'Burundi' 'Ukraine' 'Moldova' 'Armenia' 'Russia'
#  'Ivory Coast' 'Kazakhstan' 'Antigua and Barbuda' 'Bosnia-Herzegovina'
#  'Equatorial Guinea' 'Tajikistan' 'Malawi' 'Uzbekistan' 'Latvia' 'Estonia'
#  'Vietnam' 'Comoros' 'Benin' 'Slovak Republic' 'Macedonia'
#  'Wallis and Futuna' 'Belarus' 'Czech Republic' 'Slovenia' 'Gambia'
#  'North Korea' 'Eritrea' 'St. Kitts and Nevis' 'French Polynesia' 'Macau'
#  'Kyrgyzstan' 'Vanuatu' 'Democratic Republic of the Congo' 'Kosovo'
#  'Solomon Islands' 'East Timor' 'St. Lucia' 'Guinea-Bissau' 'Montenegro'
#  'International' 'Turkmenistan' 'Serbia-Montenegro' 'Bhutan' 'Serbia'
#  'South Sudan']
#
#
#
#
#                         ---------------------------------------Unique Values of Region----------------------------------------
#
#
# ['Central America & Caribbean' 'North America' 'Southeast Asia'
#  'Western Europe' 'East Asia' 'South America' 'Eastern Europe'
#  'Sub-Saharan Africa' 'Middle East & North Africa' 'Australasia & Oceania'
#  'South Asia' 'Central Asia']
#
#
#
#
#                         ---------------------------------------Unique Values of Province/State----------------------------------------
#
#
# [nan 'Federal' 'Tarlac' ... 'Carlow' 'Western Lakes' 'Vidzeme']
#
#
#
#
#                         ---------------------------------------Unique Values of City----------------------------------------
#
#
# ['Santo Domingo' 'Mexico city' 'Unknown' ... 'Hungrum' 'Ceelka Geelow'
#  'Kubentog']
#
#
#
#
#                         ---------------------------------------Unique Values of Latitude----------------------------------------
#
#
# [18.456792 19.371887 15.478598 ...  2.359673 35.407278  6.900742]
#
#
#
#
#                         ---------------------------------------Unique Values of Longitude----------------------------------------
#
#
# [-69.951164 -99.086624 120.599741 ...  45.385034  35.942679 124.437908]
#
#
#
#
#                         ---------------------------------------Unique Values of Location----------------------------------------
#
#
# [nan 'Edes Substation' 'Caparra Shopping Center' ...
#  'The incident occurred near the town of Balcad.'
#  'The incident occurred at the Humaymim Airport.'
#  'The incident occurred in the Datu Hoffer district.']
#
#
#
#
#                         ---------------------------------------Unique Values of Summary----------------------------------------
#
#
# [nan
#  '1/1/1970: Unknown African American assailants fired several bullets at police headquarters in Cairo, Illinois, United States.  There were no casualties, however, one bullet narrowly missed several police officers.  This attack took place during heightened racial tensions, including a Black boycott of White-owned businesses, in Cairo Illinois.'
#  '1/2/1970: Unknown perpetrators detonated explosives at the Pacific Gas & Electric Company Edes substation in Oakland, California, United States.  Three transformers were damaged costing an estimated $20,000 to $25,000.  There were no casualties.'
#  ...
#  '12/31/2017: Assailants set fire to houses in Kubentog, Datu Hoffer, Maguindanao, Philippines. There were no reported casualties in the attack. No group claimed responsibility for the incident; however, sources attributed the attack to the Bangsamoro Islamic Freedom Movement (BIFM).'
#  '12/31/2017: Assailants threw a grenade at a Forest Department office in Mantripukhri neighborhood, Imphal, Manipur, India. No casualties were reported in the blast. No group claimed responsibility for the incident.'
#  '12/31/2017: An explosive device was discovered and defused at a plaza in Cotabato City, Maguindanao, Philippines. No group claimed responsibility for the incident.']
#
#
#
#
#                         ---------------------------------------Unique Values of Attack Type----------------------------------------
#
#
# ['Assassination' 'Hostage Taking (Kidnapping)' 'Bombing/Explosion'
#  'Facility/Infrastructure Attack' 'Armed Assault' 'Hijacking' 'Unknown'
#  'Unarmed Assault' 'Hostage Taking (Barricade Incident)']
#
#
#
#
#                         ---------------------------------------Unique Values of Target Type----------------------------------------
#
#
# ['Private Citizens & Property' 'Government (Diplomatic)'
#  'Journalists & Media' 'Police' 'Utilities' 'Military'
#  'Government (General)' 'Airports & Aircraft' 'Business'
#  'Educational Institution' 'Violent Political Party'
#  'Religious Figures/Institutions' 'Unknown' 'Transportation' 'Tourists'
#  'NGO' 'Telecommunication' 'Food or Water Supply'
#  'Terrorists/Non-State Militia' 'Other' 'Maritime' 'Abortion Related']
#
#
#
#
#                         ---------------------------------------Unique Values of Group Name----------------------------------------
#
#
# ['MANO-D' '23rd of September Communist League' 'Unknown' ...
#  'Fatoni Warriors' 'Minorities of Metropolitan Attacks'
#  'Baloch Republican Party']
#
#
#
#
#                         ---------------------------------------Unique Values of Motive----------------------------------------
#
#
# [nan 'To protest the Cairo Illinois Police Deparment'
#  'To protest the War in Vietnam and the draft' ...
#  'The specific motive is unknown; however, sources stated that the attack was carried out in retaliation for the death of Noor Mohammad Tantray (Noor Trali), a Jaish-e-Mohammad (JeM) leader, by security personnel on December 26, 2017 in Pulwama.'
#  'The specific motive is unknown; however, sources noted that the targeted building housed migrants.'
#  'The specific motive is unknown; however, sources stated that the Taliban had warned one of the victims against collaborating with the government.']
#
#
#
#
#                         ---------------------------------------Unique Values of Weapon Type----------------------------------------
#
#
# ['Unknown' 'Explosives' 'Incendiary' 'Firearms' 'Chemical' 'Melee'
#  'Sabotage Equipment'
#  'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)'
#  'Fake Weapons' 'Radiological' 'Other' 'Biological']
#
#
#
#
#                         ---------------------------------------Unique Values of Killed----------------------------------------
#
#
# [1.000e+00 0.000e+00       nan 7.000e+00 4.700e+01 2.000e+00 3.600e+01
#  5.000e+00 3.000e+00 4.000e+00 2.500e+01 1.500e+01 2.600e+01 8.000e+00
#  8.100e+01 6.000e+00 9.000e+00 1.600e+01 3.000e+01 3.100e+01 1.200e+01
#  2.100e+01 1.400e+01 8.800e+01 1.100e+01 1.000e+01 2.700e+01 1.800e+01
#  2.200e+01 1.900e+01 9.200e+01 1.300e+01 7.300e+01 1.000e+02 4.200e+01
#  4.300e+01 1.700e+01 9.800e+01 4.220e+02 4.800e+01 3.400e+01 5.400e+01
#  5.000e+01 3.500e+01 2.000e+01 4.100e+01 3.700e+01 2.800e+01 4.000e+01
#  3.200e+01 8.500e+01 2.300e+01 3.000e+02 6.000e+01 2.400e+01 5.800e+01
#  7.000e+01 8.700e+01 4.500e+01 3.800e+01 2.900e+01 7.400e+01 8.300e+01
#  9.000e+01 6.600e+01 8.000e+01 6.700e+01 5.100e+01 3.900e+01 1.140e+02
#  1.240e+02 7.600e+01 3.300e+01 7.500e+01 5.700e+01 6.200e+01 4.600e+01
#  5.600e+01 6.300e+01 1.200e+02 1.020e+02 7.800e+01 7.900e+01 5.200e+01
#  7.700e+01 2.000e+02 4.900e+01 1.110e+02 1.650e+02 4.400e+01 2.410e+02
#  6.400e+01 1.080e+02 6.500e+01 1.320e+02 2.700e+02 2.280e+02 1.100e+02
#  1.360e+02 1.800e+02 2.500e+02 9.300e+01 1.300e+02 5.900e+01 9.400e+01
#  5.300e+01 1.460e+02 3.290e+02 9.700e+01 7.100e+01 2.400e+02 2.270e+02
#  1.260e+02 1.060e+02 3.880e+02 6.800e+01 8.400e+01 8.200e+01 1.710e+02
#  1.070e+02 5.500e+01 1.120e+02 7.200e+01 9.600e+01 1.400e+02 6.100e+01
#  1.050e+02 1.500e+02 1.150e+02 8.900e+01 1.180e+03 1.700e+02 1.680e+02
#  1.210e+02 3.750e+02 9.100e+01 3.040e+02 1.230e+02 1.350e+02 2.560e+02
#  1.090e+02 2.710e+02 2.060e+02 1.040e+02 3.200e+02 2.750e+02 2.240e+02
#  1.180e+02 1.290e+02 9.500e+01 2.590e+02 1.384e+03 1.383e+03 1.900e+02
#  1.190e+02 1.010e+02 1.160e+02 5.180e+02 3.440e+02 1.600e+02 1.880e+02
#  1.030e+02 2.050e+02 1.450e+02 1.530e+02 1.270e+02 6.900e+01 1.410e+02
#  1.340e+02 4.000e+02 8.600e+01 1.840e+02 2.100e+02 1.420e+02 2.120e+02
#  2.870e+02 3.150e+02 1.510e+02 6.700e+02 1.570e+03 3.100e+02 2.980e+02
#  9.530e+02 5.170e+02 2.010e+02 1.220e+02 1.580e+02 1.170e+02 1.440e+02
#  2.080e+02 1.520e+02 2.300e+02 2.800e+02 1.740e+02 1.430e+02 3.830e+02
#  2.830e+02 1.540e+02 2.840e+02 4.330e+02 2.660e+02 1.330e+02 1.630e+02
#  1.280e+02 5.880e+02 3.110e+02]
#
#
#
#
#                         ---------------------------------------Unique Values of Wounded----------------------------------------
#
#
# [0.000e+00       nan 1.000e+00 2.000e+00 7.000e+00 9.000e+00 1.700e+01
#  5.000e+00 3.000e+00 1.000e+01 1.200e+01 2.000e+01 4.000e+00 1.100e+01
#  2.700e+01 1.300e+01 1.900e+01 1.300e+02 5.600e+01 2.400e+01 6.000e+00
#  7.200e+01 2.380e+02 5.500e+01 1.500e+01 8.000e+00 1.800e+01 5.000e+01
#  3.400e+01 1.400e+01 7.000e+01 1.020e+02 4.100e+01 4.800e+01 3.600e+01
#  2.500e+01 8.100e+01 5.400e+01 5.300e+01 1.000e+02 4.500e+01 3.300e+01
#  4.000e+01 6.200e+01 7.400e+01 2.200e+01 3.100e+01 1.600e+01 3.000e+01
#  2.850e+02 2.300e+01 4.200e+01 4.300e+01 7.600e+01 4.400e+01 5.200e+01
#  4.600e+01 4.900e+01 1.600e+02 3.700e+01 2.100e+01 6.000e+01 7.800e+01
#  2.600e+01 2.800e+01 3.900e+01 3.800e+01 3.500e+01 3.200e+01 8.000e+01
#  4.700e+01 1.880e+02 2.150e+02 8.500e+01 7.500e+01 1.610e+02 9.000e+01
#  3.000e+02 9.500e+01 1.350e+02 6.100e+01 1.380e+02 7.100e+01 7.000e+02
#  6.600e+01 1.360e+02 1.200e+02 2.170e+02 3.190e+02 1.330e+02 6.800e+01
#  7.300e+01 2.900e+01 7.510e+02 2.000e+02 1.120e+02 2.500e+02 8.200e+01
#  1.320e+02 2.300e+02 1.070e+02 1.140e+02 8.400e+01 1.400e+02 1.500e+02
#  9.600e+01 5.100e+01 5.800e+01 6.400e+01 2.950e+02 1.060e+02 1.250e+02
#  6.900e+01 5.900e+01 5.700e+01 1.220e+02 1.090e+02 8.800e+01 1.150e+02
#  1.760e+02 2.200e+02 9.700e+01 6.500e+01 8.000e+02 1.730e+02 9.200e+01
#  5.000e+02 2.360e+02 9.800e+01 2.860e+02 1.410e+02 5.500e+03 6.500e+02
#  6.710e+02 8.600e+01 1.040e+02 8.300e+01 1.010e+02 1.272e+03 1.050e+02
#  3.860e+02 3.910e+02 1.100e+02 1.490e+02 8.900e+01 9.100e+01 1.190e+02
#  7.700e+01 1.180e+02 6.700e+01 1.700e+02 1.940e+02 1.920e+02 2.270e+02
#  2.600e+02 4.000e+03 1.800e+02 1.840e+02 9.900e+01 9.400e+01 1.370e+02
#  8.190e+03 8.191e+03 1.710e+02 1.210e+02 1.030e+02 1.620e+02 1.970e+02
#  1.510e+02 2.240e+02 1.340e+02 2.330e+02 1.670e+02 4.500e+02 2.160e+02
#  1.450e+02 6.300e+01 7.270e+02 1.820e+02 1.590e+02 1.080e+02 1.280e+02
#  3.400e+02 1.630e+02 5.420e+02 8.700e+01 1.550e+02 8.170e+02 2.570e+02
#  1.480e+02 1.230e+02 2.460e+02 1.270e+02 3.470e+02 1.780e+02 1.680e+02
#  2.070e+02 1.830e+02 1.170e+02 7.500e+02 1.470e+02 1.001e+03 9.300e+01
#  1.540e+02 2.350e+02 1.580e+02 2.110e+02 1.160e+02 2.760e+02 5.520e+02
#  3.600e+02 1.130e+02 1.570e+02 1.750e+02 3.010e+02 1.310e+02 4.000e+02
#  3.700e+02 8.500e+00 1.690e+02 2.010e+02 1.110e+02 1.430e+02 1.530e+02
#  1.240e+02 7.900e+01 2.700e+02 1.520e+02 2.960e+02 2.450e+02 1.500e+03
#  3.510e+02 6.000e+02 4.330e+02 1.770e+02 4.910e+02 4.050e+02 8.510e+02
#  3.160e+02]
#
#
#
#
#                         ---------------------------------------Unique Values of Add Notes----------------------------------------
#
#
# [nan
#  'The Cairo Chief of Police, William Petersen, resigned as a result of the attack.'
#  'Damages were estimated to be between $20,000-$25,000.' ...
#  'The victims included police commander Faqeer Ahmad. Casualty numbers conflict across sources. Following GTD protocol, the majority reliable estimates are reported here.'
#  'The victims included the owner, Norodin Pacalna, and employee Jamil Umraan.'
#  'The victims included Senior Police Officer 4 Max Kaibat, Police Officer 3 Jalison Abdullah and Police Officers 1 Archie Ansare Amelista, Ricardo Almonia, Alimodin Nuphay and Zainoden Abdullah. Casualty numbers conflict across sources. Following GTD protocol, the majority reliable estimates are reported here.']

# %% [markdown]
# Now , we have --------------------
#
# 1.(181691 rows and  19 columns)
#
# 2.A lot of missing values are present ,which we have to handle them by replacing with 0.

# %%
#Handling Missing Values in killed and wounded column,and also creating a new column  from both---------------------

df["Killed"]=df["Killed"].fillna(0)
df["Wounded"]=df["Wounded"].fillna(0)
df["Casualty"]=df["Killed"]+df["Wounded"]

# %%
#take a look on dataset
df.head()
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
#
#   Province/State           City   Latitude   Longitude Location Summary  \
# 0            NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1        Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2         Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3         Attica         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                       Attack Type                  Target Type  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                            Group Name Motive Weapon Type  Killed  Wounded  \
# 0                              MANO-D    NaN     Unknown     1.0      0.0
# 1  23rd of September Communist League    NaN     Unknown     0.0      0.0
# 2                             Unknown    NaN     Unknown     1.0      0.0
# 3                             Unknown    NaN  Explosives     0.0      0.0
# 4                             Unknown    NaN  Incendiary     0.0      0.0
#
#   Add Notes  Casualty
# 0       NaN       1.0
# 1       NaN       0.0
# 2       NaN       1.0
# 3       NaN       0.0
# 4       NaN       0.0

# %%
#Statistical Description of Dataset
df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded       Casualty
# count  1.771340e+05  181691.000000  181691.000000  181691.000000
# mean  -4.586957e+02       2.266860       2.883296       5.150156
# std    2.047790e+05      11.227057      34.309747      40.555416
# min   -8.618590e+07       0.000000       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000       1.000000
# 75%    6.871033e+01       2.000000       2.000000       4.000000
# max    1.793667e+02    1570.000000    8191.000000    9574.000000

# %% [markdown]
# Observation:------------
#
#
# 1.The data consists of terrorist activities ranging from the year: 1970 to 2017
#
# 2.Maximum number of people killed in an event were: 1570
#
# 3.Maximum number of people wounded in an event were: 8191
#
# 4.Maximum number of total casualties in an event were: 9574

# %% [markdown]
# ## 4.EDA---Let's Explore The Data Visually

# %% [markdown]
# ### a).Year wise Killed,Wounded,Attacks and Casualties

# %%
#total attacks in each year
attacks=df["Year"].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={"index":"Year","Year":"Attacks"}).set_index("Year")
attacks.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# observation------------------
#
#     1. Most number of attacks in 2014
#
#     2. Least number of attacks in 1971

# %%
#Let's see total wounded ,Casualty and killed  in each year
col1=['Wounded','Killed','Casualty']
for i in col1:
    yc=df[["Year",i]].groupby("Year").sum()
    yc.plot(kind="bar",figsize=(15,6))
    plt.title(f"Year wise {i}",fontsize=18)
    plt.xlabel("Years",fontsize=13)
    plt.xticks(fontsize=12)
    plt.ylabel(f"Number of {i}",fontsize=18)
    plt.show()

# %% [markdown]
# ### b).Region wise Killed,Wounded,Attacks and Casualties

# %%
for i in col1: 
    rc=df[["Region",i]].groupby("Region").sum().sort_values(by=i,ascending=True)
    rc.plot(kind="barh",color="green",figsize=(18,9))
    plt.title(f"Region wise {i}",fontsize=18)
    plt.xlabel("Region",fontsize=13)
    plt.xticks(fontsize=12)
    plt.ylabel(f"Number of {i}",fontsize=18)
    plt.show()

# %% [markdown]
# ### c).Country wise Killed,Wounded,Attacks and Casualties

# %%
#no. of attacks in each country
ctt=df["Country"].value_counts().head(10)
ctt
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
ctt.plot(kind="bar",color="Blue")
plt.title(f"Total Attacks in each country",fontsize=18)
plt.show()

# %%
for i in col1: 
    gc=df[["Country",i]].groupby("Country").sum().sort_values(by=i,ascending=False)[:10]
    gc.plot(kind="bar",color="red",figsize=(18,9))
    plt.title(f"Country wise {i}",fontsize=18)
    plt.xlabel("Country",fontsize=13)
    plt.xticks(fontsize=12)
    plt.ylabel(f"Number of {i}",fontsize=18)
    plt.show()

# %% [markdown]
# ### d).City wise Killed,Wounded,Attacks and Casualties

# %%
for i in col1: 
    cc=df[["City",i]].groupby("City").sum().sort_values(by=i,ascending=False).drop("Unknown")[:10]
    cc.plot(kind="bar",color="purple",figsize=(18,9))
    plt.title(f"City wise {i}",fontsize=18)
    plt.xlabel("City",fontsize=13)
    plt.xticks(fontsize=12)
    plt.ylabel(f"Number of {i}",fontsize=18)
    plt.show()

# %% [markdown]
# ### e).Terrorist Group wise Attacks Killed,Wounded,Attacks and Casualties

# %%
#Number of Attacks by each Group
grp=df["Group Name"].value_counts()[1:10]
grp
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Name: Group Name, dtype: int64

# %%
grp.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
for i in col1: 
    cc=df[["Group Name",i]].groupby("Group Name").sum().sort_values(by=i,ascending=False).drop("Unknown")[:10]
    cc.plot(kind="bar",color="blue",figsize=(18,9))
    plt.title(f"Terrorist Group Name wise {i}",fontsize=18)
    plt.xlabel("Group Name",fontsize=13)
    plt.xticks(fontsize=12)
    plt.ylabel(f"Number of {i}",fontsize=18)
    plt.show()

# %% [markdown]
# ### f).Attack Type wise  Killed,Wounded,Attacks and Casualties

# %%
at=df["Attack Type"].value_counts()
at
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attack Type, dtype: int64

# %%
at.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
for i in col1: 
    att=df[["Attack Type",i]].groupby("Attack Type").sum().sort_values(by=i,ascending=False)
    att.plot(kind="bar",color="green",figsize=(18,9))
    plt.title(f"Attack Type wise {i}",fontsize=18)
    plt.xlabel("Attack Type",fontsize=13)
    plt.xticks(fontsize=12)
    plt.ylabel(f"Number of {i}",fontsize=18)
    plt.show()

# %% [markdown]
# ### g).Target Type wise Killed,Wounded,Attacks and Casualties

# %%
ta=df["Target Type"].value_counts()
ta
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: Target Type, dtype: int64

# %%
ta.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
for i in col1: 
    ttt=df[["Target Type",i]].groupby("Target Type").sum().sort_values(by=i,ascending=False)
    ttt.plot(kind="bar",color="red",figsize=(18,9))
    plt.title(f"Target Type wise {i}",fontsize=18)
    plt.xlabel("Target Type",fontsize=13)
    plt.xticks(fontsize=12)
    plt.ylabel(f"Number of {i}",fontsize=18)
    plt.show()

# %% [markdown]
# ### h).Group Name wise Killed,Wounded,Attacks and Casualties

# %%
gca=df[["Group Name","Country"]].value_counts().drop("Unknown")
gca.head(10)
# Out:
# C:\Users\91639\AppData\Local\Temp\ipykernel_26760\390661980.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gca=df[["Group Name","Country"]].value_counts().drop("Unknown")
# Group Name                                        Country
# Taliban                                           Afghanistan       7423
# Islamic State of Iraq and the Levant (ISIL)       Iraq              4797
# Shining Path (SL)                                 Peru              4541
# Farabundo Marti National Liberation Front (FMLN)  El Salvador       3330
# Al-Shabaab                                        Somalia           2867
# New People's Army (NPA)                           Philippines       2770
# Irish Republican Army (IRA)                       United Kingdom    2575
# Revolutionary Armed Forces of Colombia (FARC)     Colombia          2468
# Kurdistan Workers' Party (PKK)                    Turkey            2109
# Boko Haram                                        Nigeria           2087
# dtype: int64

# %%
gca.head(10).plot(kind="bar",color="cornflowerblue",figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Group Name,Country'>

# %%
for i in col1: 
    ttt=df[["Target Type",i]].groupby("Target Type").sum().sort_values(by=i,ascending=False)
    ttt.plot(kind="bar",color="red",figsize=(18,9))
    plt.title(f"Target Type wise {i}",fontsize=18)
    plt.xlabel("Target Type",fontsize=13)
    plt.xticks(fontsize=12)
    plt.ylabel(f"Number of {i}",fontsize=18)
    plt.show()

# %% [markdown]
# ### i).Humanity Affected (World-wide) by Terrorist Attacks from 1970 to 2017

# %%
for i in col1:
    cc=df.loc[:,i].sum()
    print(f"Total number of {i} due to Terrorist Attacks from 1970 to 2017 across the world :",cc)
# Out:
# Total number of Wounded due to Terrorist Attacks from 1970 to 2017 across the world : 523869.0
# Total number of Killed due to Terrorist Attacks from 1970 to 2017 across the world : 411868.0
# Total number of Casualty due to Terrorist Attacks from 1970 to 2017 across the world : 935737.0

# %% [markdown]
# CONCLUSION---------------------------------------------------------------------------------------------------------------
#
# 1. Year wise Attacks :
#
#   (i) Attacks
#
#      (a) Most number of attacks: 16903 in 2014
#
#      (b) Least number of attacks: 471 in 1971
#
#
#   (ii) Casualties
#
#     (a) Most number of casualties: 85618 in 2014
#
#     (b) Least number of casualties: 255 in 1971
#
#
#   (iii) Killed
#
#     (a) Most number of people killed: 44490 in 2014
#
#     (b) Least number of people killed: 173 in 1971
#
#
#   (iv) Wounded
#
#     (a) Most number of people wounded: 44043 in 2015
#
#     (b) Least number of people wounded: 82 in 1971
#
#
#
# 2. Region wise Attacks :
#
#   (i) Attacks
#
#     (a) Most number of attacks: 50474 in "Middle East & North Africa"
#
#     (b) Least number of attacks: 282 in "Australasia & Oceania"
#
#
#
#   (ii) Casualties
#
#     (a) Most number of casualties: 351950 in "Middle East & North Africa"
#
#     (b) Least number of casualties: 410 in Australasia & Oceania
#
#   (iii) Killed
#
#     (a) Most number of people killed: 137642 in "Middle East & North Africa"
#
#     (b) Least number of people killed: 150 in "Australasia & Oceania"
#
#
#
#   (iv) Wounded
#
#     (a) Most number of people wounded: 214308 in "Middle East & North Africa"
#
#     (b) Least number of people wounded: 260 in "Australasia & Oceania"
#
#
#
#
# 3. Country wise Attacks :
#
#   (i) Attacks
#
#     (a) Most number of attacks: 24636 in "Iraq"
#
#     (b) Least number of attacks: 4292 in "Turkey"
#
#
#
#
#   (ii) Casualties
#
#     (a) Most number of casualties: 213279 in "Iraq"
#
#     (b) Least number of casualties: 22926 in "Philippines"
#
#
#
#   (iii) Killed
#
#     (a) Most number of people killed: 78589 in "Iraq"
#
#     (b) Least number of people killed: 12053 in "El Salvador"
#
#
#
#   (iv) Wounded
#
#     (a) Most number of people wounded: 134690 in "Iraq"
#
#     (b) Least number of people wounded: 10328 in "Colombia"
#
#
#
#
# 4. City wise Attacks :
#
#   (i) Attacks
#
#     (a) Most number of attacks: 7589 in "Baghdad"
#
#     (b) Least number of attacks: 1019 in "Athens"
#
#
#
#   (ii) Casualties
#
#     (a) Most number of casualties: 77876 in "Baghdad"
#
#     (b) Least number of casualties: 5748 in "Aleppo"
#
#
#
#   (iii) Killed
#
#     (a) Most number of people killed: 21151 in "Baghdad"
#
#     (b) Least number of people killed: 2125 in "Aleppo"
#
#
#
#   (iv) Wounded
#
#     (a) Most number of people wounded: 56725 in "Baghdad"
#
#     (b) Least number of people wounded: 4955 in "Mogadishu"
#
#
#
#
# 5. Terrorist Group wise Attacks  :
#
#   (i) Attacks
#
#     (a) Most number of attacks : 7478 by "Taliban"
#
#     (b) Least number of attacks : 2418 by "Boko Haram"
#
#
#
#   (ii) Casualties
#
#     (a) Most number of casualties : 69595 by "Islamic State of Iraq and the Levant (ISIL)"
#
#     (b) Least number of casualties : 12130 by "Farabundo Marti National Liberation Front (FMLN)"
#
#
#
#   (iii) Killed
#
#     (a) Most number of people killed : 38923 by "Islamic State of Iraq and the Levant (ISIL)"
#
#     (b) Least number of people killed : 5661 by "Revolutionary Armed Forces of Colombia (FARC)"
#
#
#
#   (iv) Wounded
#
#     (a) Most number of people wounded : 30672 by "Islamic State of Iraq and the Levant (ISIL)"
#
#     (b) Least number of people wounded : 4908 by "Kurdistan Workers' Party (PKK)"
#
#
#
# 6. Attack Type wise Attacks:
#
#   (i) Attacks
#
#     (a) Most number of attacks : 88255 by "Bombing/Explosion"
#
#     (b) Least number of attacks : 659 by "Hijacking"
#
#
#
#   (ii) Casualties
#
#     (a) Most number of casualties : 530007 by "Bombing/Explosion"
#
#     (b) Least number of casualties : 7407 by "Facility/Infrastructure Attack"
#
#
#
#   (iii) Killed
#
#     (a) Most number of people killed : 160297 by "Armed Assault"
#
#     (b) Least number of people killed : 880 by "Unarmed Assault"
#
#
#
#   (iv) Wounded
#
#     (a) Most number of people wounded : 372686 by "Bombing/Explosion"
#
#     (b) Least number of people wounded : 3765 by "Facility/Infrastructure Attack"
#
#
#
#
# 7. Target Type wise Attacks:
#
#   (i) Attacks
#
#     (a) Most number of attacks : 43511 over "Private Citizens & Property"
#
#     (b) Least number of attacks : 263 over "Abortion Related"
#
#
#
#   (ii) Casualties
#
#     (a) Most number of casualties : 319176 over "Private Citizens & Property"
#
#     (b) Least number of casualties : 56 over "Abortion Related"
#
#
#
#   (iii) Killed
#
#     (a) Most number of people killed : 140504 over "Private Citizens & Property"
#
#     (b) Least number of people killed : 10 over "Abortion Related"
#
#
#
#   (iv) Wounded
#
#     (a) Most number of people wounded : 178672 over "Private Citizens & Property"
#
#     (b) Least number of people wounded : 46 over "Abortion Related"
#
#
#
#
# 8. Group and Country wise Attacks :
#
#   (i) Attacks
#
#     (a) Most number of attacks : 7423 by "Taliban" in "Afghanistan"
#
#     (b) Least number of attacks : 2087 by "Boko Haram" in "Nigeria"
#
#
#
#   (ii) Casualties
#
#     (a) Most number of casualties : 57140 by "Taliban" in "Afghanistan"
#
#     (b) Least number of casualties : 12068 by "Farabundo Marti National Liberation Front (FMLN)" in "El Salvador"
#
#
#
#   (iii) Killed
#
#     (a) Most number of people killed : 31058 by "Islamic State of Iraq and the Levant (ISIL)" in "Iraq"
#
#     (b) Least number of people killed : 6014 by "Tehrik-i-Taliban Pakistan (TTP)" in "Pakistan"
#
#
#
#   (iv) Wounded
#
#     (a) Most number of people wounded : 27871 by "Taliban" in "Afghanistan"
#
#     (b) Least number of people wounded : 4795 by "Kurdistan Workers' Party (PKK)" in "Turkey"
#
#
#
#
# 9. Humanity Affected (World-wide) by Terrorist Attacks from 1970 to 2017 :
#
#   (i) Total number of Casualties due to Terrorist Attacks from 1970 to 2017 across the world : 935737
#
#   (ii) Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world : 411868
#
#   (iii) Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world : 523869
